# %% [markdown]
# ## Задание X

# %%
# импортируем модули
import matplotlib.pyplot as plt
import numpy as np
# размер фигуры matplotlib по-умолчанию
plt.rcParams['figure.figsize'] = [13, 8]

# %% [markdown]
# ### Загружаем трейсы

# %%
textin = np.load('traces/textin.npy')
textout = np.load('traces/textout.npy')
traces = np.load('traces/traces.npy')
print(np.shape(textin))
print(textin[0])
print(textin[1])
# Out:
# (100, 16)
# [156 135   7 127 141 111 213 234 169 189 200 111 126 215 234 164]
# [126  27 171  96 137 164  70  37  13 155 105 103 197  87  33 147]

# %%
ntraces = np.shape(traces)[0]
nsamples = np.shape(traces)[1]
print(np.shape(traces))
print(ntraces,nsamples)
# Out:
# (100, 5000)
# 100 5000

# %% [markdown]
# Рисуем несколько, чтобы проверить выравнивание:

# %%
start = 850
end =1700
# for i in range(ntraces):
#    plt.plot(traces[i][start:end], linewidth=.3)
plt.plot(traces[1][start:end])
plt.show()

# %% [raw]
# ### CPA
#
# Определим нашу модель: первый раунд AES после операции подстановки (SubBytes)

# %%
# Hemming Weight
hw = [bin(n).count("1") for n in range(0,256)]

# AES SBox
sbox = (
)

# Leakage function
def leakage(data, key_guess):
    return hw[sbox[data ^ key_guess]]

# %%
def correlation(hypothesis):   
    max_correlation=0.0
    max_correlation_time=start    
    for timemoment in range(start, end):
        samples = np.copy(traces[:,timemoment])
        
        correlation=abs(np.corrcoef(hypothesis, samples)[1,0])
        if correlation>max_correlation:
            max_correlation_time=timemoment
            max_correlation=correlation         
               
    return max_correlation,max_correlation_time

# %%
def tr_shifting(x, y):
    return sum(abs((x-y)))

start_window = 800     
end_window = 1200      
len_window = end_window - start_window

start_range = 100     
end_range = 4000

diffs = [0, ]         
for trace in traces[1:]:
    diff = 0
    min_tr_shifting = 10005000000000         

    for i in range(start_range, end_range):
        if i + len_window > end_range:    
            break
        tmp_tr_shifting = tr_shifting(traces[0][start_window:end_window], trace[i:i + len_window])
        if tmp_tr_shifting < min_tr_shifting:
            min_tr_shifting = tmp_tr_shifting
            diff = i - start_window    
    diffs.append(diff)

# %%
traces_amount = len(textin)
meas_amount = len(traces[0])

start = abs(min(diffs))
end = meas_amount - max(diffs)
for i in range(traces_amount):
    plt.plot(np.arange(start, end), traces[i][start:end], linewidth=0.2)
plt.show()
for i in range(traces_amount):
    plt.plot(np.arange(start, end), traces[i][start+diffs[i]:end+diffs[i]], linewidth=0.2)
plt.show()
for i in range(20):
    plt.plot(np.arange(start, end), traces[i][start:end] + i, linewidth=0.2)
plt.show()

for i in range(20):
    plt.plot(np.arange(start, end), traces[i][start+diffs[i]:end+diffs[i]] + i, linewidth=0.2)
plt.show()
print(start, end)
# Out:
# 0 5000

# %%
def key_guesses_text(coefs, n=3):
    best_guesses = np.argsort(coefs)[::-1][:n]
    desc = []
    tmpl = "key guess: %02x (%06f)" 
    for guess in np.nditer(best_guesses):
        desc.insert(0, tmpl % (guess, coefs[guess]))
    return ", ".join(desc)

key = np.zeros(16)
# for each key byte
for key_byte_num in range(16):
    maxcpa = np.zeros(256)
    maxtime=np.zeros(256)
    # for each key guess at key_byte_num place
    for key_guess in range(0, 256):
        # calculate leakage for data on each trace
        hyp = np.zeros(ntraces)
        for tnum in range(ntraces):
            hyp[tnum] = leakage(textin[tnum][key_byte_num], key_guess)
        [corr, timemoment] = correlation(hyp)
        maxcpa[key_guess] = corr
        maxtime[key_guess]=timemoment
    key[key_byte_num] = np.argmax(maxcpa)
    print("Time: %d Position #%02d: %s" % (maxtime[np.argmax(maxcpa)], key_byte_num, key_guesses_text(maxcpa)))
# Out:
# Time: 954 Position #00: key guess: 4e (0.895379), key guess: a5 (0.489897), key guess: a3 (0.444138)
# Time: 1129 Position #01: key guess: 30 (0.842721), key guess: 3b (0.428834), key guess: b0 (0.414979)
# Time: 1306 Position #02: key guess: 5f (0.894691), key guess: 95 (0.448951), key guess: fd (0.438338)
# Time: 1482 Position #03: key guess: 47 (0.857788), key guess: fd (0.421860), key guess: 8e (0.416280)
# Time: 994 Position #04: key guess: 75 (0.886301), key guess: 38 (0.474158), key guess: 66 (0.434587)
# Time: 1686 Position #05: key guess: 54 (0.873932), key guess: 0a (0.418044), key guess: c9 (0.399801)
# Time: 1346 Position #06: key guess: 35 (0.908848), key guess: 62 (0.454035), key guess: 88 (0.445918)
# Time: 1521 Position #07: key guess: 5f (0.871757), key guess: cd (0.449280), key guess: 0d (0.441875)
# Time: 1033 Position #08: key guess: 4e (0.863442), key guess: 0e (0.415277), key guess: aa (0.412793)
# Time: 1210 Position #09: key guess: 6f (0.833466), key guess: 9e (0.426010), key guess: 0d (0.420501)
# Time: 1386 Position #10: key guess: 5f (0.899747), key guess: c6 (0.427388), key guess: d4 (0.426429)
# Time: 1562 Position #11: key guess: 53 (0.886950), key guess: 6c (0.442573), key guess: 47 (0.434635)
# Time: 1074 Position #12: key guess: 37 (0.872134), key guess: d2 (0.447741), key guess: 82 (0.417365)
# Time: 1250 Position #13: key guess: 30 (0.869233), key guess: a0 (0.466711), key guess: 4b (0.442340)
# Time: 1426 Position #14: key guess: 52 (0.826963), key guess: 12 (0.474275), key guess: 89 (0.440442)
# Time: 1602 Position #15: key guess: 59 (0.805593), key guess: cc (0.442892), key guess: 9b (0.420123)

# %%
plt.plot(maxcpa)
plt.show()
np.save('traces/key.npy',key)
key1=np.load('traces/key.npy')
key2=key1.astype('B')
key3=key2.tobytes()
key4=key3
key4
print (bytes(key4))
#key4=b'\x4e\x3b\xfd\xcf\x75\x0a\xcb\x9a\x4e\x9e\xd4\xc8\x37\x0f\x3c\xcc'
# Out:
# b'N0_GuT5_No_S70RY'

# %%
from Crypto.Cipher import AES
key_found=b'N0_GuT5_No_S70RY'
cipher = AES.new(key_found, AES.MODE_ECB)
cipher2 = AES.new(key4, AES.MODE_ECB)

for TextNumber in range(ntraces):
    intext0=textin[TextNumber]
    intext1=intext0.astype('B')
    intext2=intext1.tobytes()
    encrypted_text = cipher2.encrypt(intext2)
    outtext0=textout[TextNumber]
    outtext1=outtext0.astype('B')
    outtext2=outtext1.tobytes()
    print(outtext2, encrypted_text)
# Out:
# b'\xb3e<\x05i\xec\xb1\x8a\x83\xc8\x91\n\xcax%R' b'\xb3e<\x05i\xec\xb1\x8a\x83\xc8\x91\n\xcax%R'
# b'\x86e\xff\xf5\xf6\xc0.6\x81\xed\x8e\xde)\xad\x06\xb6' b'\x86e\xff\xf5\xf6\xc0.6\x81\xed\x8e\xde)\xad\x06\xb6'
# b'd\x85\x0e\xe1Z\x92P\xaf\xb3aN\x8fGQ\xb8\x8d' b'd\x85\x0e\xe1Z\x92P\xaf\xb3aN\x8fGQ\xb8\x8d'
# b'\xe3\x98\x9f\xcb\xe6\xdc\xa5\xbdO:\xb3\x8eUr\xa3\x89' b'\xe3\x98\x9f\xcb\xe6\xdc\xa5\xbdO:\xb3\x8eUr\xa3\x89'
# b'\x18\x08;1\xafC\x15\xfaVm\x8e\xf3}\xa1\x16\x18' b'\x18\x08;1\xafC\x15\xfaVm\x8e\xf3}\xa1\x16\x18'
# b'\x07\x88\xe0|\x86\xdd\xb1\x107\xc9\xc4F\x9cY |' b'\x07\x88\xe0|\x86\xdd\xb1\x107\xc9\xc4F\x9cY |'
# b'\x8e%k0\xd6\x83~\x9e\xf7\xd3\x0cb\xa0B\x0e\x13' b'\x8e%k0\xd6\x83~\x9e\xf7\xd3\x0cb\xa0B\x0e\x13'
# b'\xc2\xcfGU\x07i\xc6\x14~\x15g\x8cq\xb3K\xa7' b'\xc2\xcfGU\x07i\xc6\x14~\x15g\x8cq\xb3K\xa7'
# b'>\xbap\x14<\xd0\x1a\x86\xb9jo\xd7\x18<lX' b'>\xbap\x14<\xd0\x1a\x86\xb9jo\xd7\x18<lX'
# b'\x80\xcc\x19\xc2\x9f\x8f\xcb\x18\xe1\xe4y\xd8n\xb9\x14n' b'\x80\xcc\x19\xc2\x9f\x8f\xcb\x18\xe1\xe4y\xd8n\xb9\x14n'
# b'\xd6g\xec\x1d\x12\x89\xe15}\x91\xdb\x95\xdb4}\xb6' b'\xd6g\xec\x1d\x12\x89\xe15}\x91\xdb\x95\xdb4}\xb6'
# b"r\x03\x12\xf4\x08\xc1\x9c\x8e\x1f\xb8JGV\xa5\xe8'" b"r\x03\x12\xf4\x08\xc1\x9c\x8e\x1f\xb8JGV\xa5\xe8'"
# b'9\x83R\x10\x1d\x9f\xf3\x13L6\xe2\xa49b2\xee' b'9\x83R\x10\x1d\x9f\xf3\x13L6\xe2\xa49b2\xee'
# b'\xad\xd9yJ\x01\x8cvJ\x01\\*\xaf\xa2\xa0\x18\x9e' b'\xad\xd9yJ\x01\x8cvJ\x01\\*\xaf\xa2\xa0\x18\x9e'
# b'\xb0\xe7\n\x15\x8c\x16S\x9a\x10v)\n\xc3\xfcy\xf6' b'\xb0\xe7\n\x15\x8c\x16S\x9a\x10v)\n\xc3\xfcy\xf6'
# b'\x85\x13\xd2\x08\r\x10\xbc\x06\xd8\xbe\xf3\xc7W \xbf\xf5' b'\x85\x13\xd2\x08\r\x10\xbc\x06\xd8\xbe\xf3\xc7W \xbf\xf5'
# b'\xd4\x96a\xf9\xdeZ\xa4I\x85\xf0YD\xbd\xc1!\xbe' b'\xd4\x96a\xf9\xdeZ\xa4I\x85\xf0YD\xbd\xc1!\xbe'
# b'\xe1\x1co\x94b\x97H\x90\x05\xc1\xe0\x88\x07\xb8\xdf|' b'\xe1\x1co\x94b\x97H\x90\x05\xc1\xe0\x88\x07\xb8\xdf|'
# b'\xa7\xf5\xa6\x9cp$\xf2\x8f\xf2JuU\x95\x9c\x00\xd6' b'\xa7\xf5\xa6\x9cp$\xf2\x8f\xf2JuU\x95\x9c\x00\xd6'
# b'\xb9\xd5\\\x06\xdbQ\xe8\xba\xb9\x86\xb2\xced\x030\xd0' b'\xb9\xd5\\\x06\xdbQ\xe8\xba\xb9\x86\xb2\xced\x030\xd0'
# b'\xdb\x08biE\x1e\xd8]\xf1}m\xff[\xc5\x1a\x84' b'\xdb\x08biE\x1e\xd8]\xf1}m\xff[\xc5\x1a\x84'
# b'\xf7\x0e\xe0\x95\x9a\xfdV"\x94g\xe54M\xe28\x01' b'\xf7\x0e\xe0\x95\x9a\xfdV"\x94g\xe54M\xe28\x01'
# b'Q\x90\xbe\xc2~\xe6)\xf5!\xae~G\xe1 qK' b'Q\x90\xbe\xc2~\xe6)\xf5!\xae~G\xe1 qK'
# b'\xc7\xcbR\xf0g\xb7+\x83\x07}\xcbk\xd4r\x1d\x83' b'\xc7\xcbR\xf0g\xb7+\x83\x07}\xcbk\xd4r\x1d\x83'
# b'\x0ce!m\xa5Q7\x9a\x86k\xe6\xa0(\xb9M\x84' b'\x0ce!m\xa5Q7\x9a\x86k\xe6\xa0(\xb9M\x84'
# b'B\xbab\x9eT\x15?1\xbb\xfa\xc9\xa3S}F\x88' b'B\xbab\x9eT\x15?1\xbb\xfa\xc9\xa3S}F\x88'
# b'\xdeJ\xa9\xfd\x03y\x9e\xc6\x017g\x93\x00h\xadc' b'\xdeJ\xa9\xfd\x03y\x9e\xc6\x017g\x93\x00h\xadc'
# b'\xfe\xc6\x9d,\x9a?\xea\xe3\xcf\x82*\xc2\x86\x05\x80\xcf' b'\xfe\xc6\x9d,\x9a?\xea\xe3\xcf\x82*\xc2\x86\x05\x80\xcf'
# b'\x0f\x86\xef\xb2\x9e\x84Ly>{\x9a\x8b\x1a\x80\xe5\x9c' b'\x0f\x86\xef\xb2\x9e\x84Ly>{\x9a\x8b\x1a\x80\xe5\x9c'
# b'\x9f1\x9c2\xfe\x9dq\xb09\xe8\\\xe4\xbd\xde\x8a\xda' b'\x9f1\x9c2\xfe\x9dq\xb09\xe8\\\xe4\xbd\xde\x8a\xda'
# b'\xc6\x92\x95\xa8f\x9d\x11\xc3|\xbc2\x92B\x17\xabv' b'\xc6\x92\x95\xa8f\x9d\x11\xc3|\xbc2\x92B\x17\xabv'
# b'we\x12++\x0e:Q5Wi\xf6\x18\x9dR\x18' b'we\x12++\x0e:Q5Wi\xf6\x18\x9dR\x18'
# b'\xe7\x89i\xfd\x81\x18\xb8\xe5Q\x02\r\x98\x10z\xec~' b'\xe7\x89i\xfd\x81\x18\xb8\xe5Q\x02\r\x98\x10z\xec~'
# b'\xf9N+\xd7\xc0d\x1b\xce\xe2\x1a\xcc+\xee\xef#\xaf' b'\xf9N+\xd7\xc0d\x1b\xce\xe2\x1a\xcc+\xee\xef#\xaf'
# b'\x0e\xda\xbd?\xcaC\x1b i\xc5\xd3\x8a\xbe!L\x0e' b'\x0e\xda\xbd?\xcaC\x1b i\xc5\xd3\x8a\xbe!L\x0e'
# b"'H\xec|\x94\xed\xbb/\xee[\xd6\xa6yM\rr" b"'H\xec|\x94\xed\xbb/\xee[\xd6\xa6yM\rr"
# b'\x1f\x013\x1fW\xf8\xfa\xee\x88\x95T:\x86\xe7?\xbe' b'\x1f\x013\x1fW\xf8\xfa\xee\x88\x95T:\x86\xe7?\xbe'
# b'\xd0c\x11/\x80xJY\x07;\x18U9\xdb\xda\xe3' b'\xd0c\x11/\x80xJY\x07;\x18U9\xdb\xda\xe3'
# b'\x8e\x9b\x01\x08\x86\x81\x06x\xaaw\x84\xc5\xcdE7\xcf' b'\x8e\x9b\x01\x08\x86\x81\x06x\xaaw\x84\xc5\xcdE7\xcf'
# b'\xd6\xc84.\x95\x1f\xa6\xc6\x1eYl\x19\x1f\x1b\x02\xaa' b'\xd6\xc84.\x95\x1f\xa6\xc6\x1eYl\x19\x1f\x1b\x02\xaa'
# b'\x9bK*\xeb\x87\xce\xe01\x90\x84\xcc\xaa\x15\xa7\xa8O' b'\x9bK*\xeb\x87\xce\xe01\x90\x84\xcc\xaa\x15\xa7\xa8O'
# b'7Jq\x00\xea\xf2z&y\x10\x19\xa7\x86r\x1et' b'7Jq\x00\xea\xf2z&y\x10\x19\xa7\x86r\x1et'
# b"\xdey\xab\x01I [\xa4k\xa6\xa4]r'\n\xbb" b"\xdey\xab\x01I [\xa4k\xa6\xa4]r'\n\xbb"
# b'\x04\x1b\xe4\x82\x1f\xb0\x9f\t\x90\xf8\xfc\xeb\x1b\xabX\xc2' b'\x04\x1b\xe4\x82\x1f\xb0\x9f\t\x90\xf8\xfc\xeb\x1b\xabX\xc2'
# b'!\x87w\xe7T\x99U\xbbbZ\xd9\xd0\xad\xf0\xfdk' b'!\x87w\xe7T\x99U\xbbbZ\xd9\xd0\xad\xf0\xfdk'
# b'\xfb-G\xf3\xa7\x8d\xf5\xde\xe5\xad\xa6\x01i\x8b\xa4\xe6' b'\xfb-G\xf3\xa7\x8d\xf5\xde\xe5\xad\xa6\x01i\x8b\xa4\xe6'
# b'\x85G\xca\xf7\x9c\x99\x0c\xf9/\x1b\xcd\x17\x94E\xcb\x9e' b'\x85G\xca\xf7\x9c\x99\x0c\xf9/\x1b\xcd\x17\x94E\xcb\x9e'
# b'\xe6\xdab\xa6\xdeh\xe4C\xe715\x87_\xd0rq' b'\xe6\xdab\xa6\xdeh\xe4C\xe715\x87_\xd0rq'
# b'\x8b\xb0`\r\x91\x87\xd8\xf5\xe8\xd9\xa2;u\xcb\x87v' b'\x8b\xb0`\r\x91\x87\xd8\xf5\xe8\xd9\xa2;u\xcb\x87v'
# b'9\xf9\x97~XS\xb9\xd9\x08\x08?\xa2>Tm2' b'9\xf9\x97~XS\xb9\xd9\x08\x08?\xa2>Tm2'
# b'x\x0b4\xa2\x04\x9e\xe7\x0f\x14V\xac\x8bR/\x80\xac' b'x\x0b4\xa2\x04\x9e\xe7\x0f\x14V\xac\x8bR/\x80\xac'
# b"{\x9c\xfbS\xd7:\x9e\x04-$\xf5'\xa0!\x14\xac" b"{\x9c\xfbS\xd7:\x9e\x04-$\xf5'\xa0!\x14\xac"
# b'`\x15a\x8f\xa9L2\xcbq\x7f\x87\xe1\xd8K\xe7\xa0' b'`\x15a\x8f\xa9L2\xcbq\x7f\x87\xe1\xd8K\xe7\xa0'
# b'\x1d\xfb\xf6yH<;\x8c\xdff\xcc\x03\xdd\x82U\xaf' b'\x1d\xfb\xf6yH<;\x8c\xdff\xcc\x03\xdd\x82U\xaf'
# b"w~\x9cC'\xd8T\x89\x89\xfc>-\xbe\x15\xee\x07" b"w~\x9cC'\xd8T\x89\x89\xfc>-\xbe\x15\xee\x07"
# b'\xb1@\x9e\xec|\x88p^\xc7\x02e\xb5:\xdf\xc6(' b'\xb1@\x9e\xec|\x88p^\xc7\x02e\xb5:\xdf\xc6('
# b'4#XP\x11\xb5PPn\xc6\x18\xbc^Y_\r' b'4#XP\x11\xb5PPn\xc6\x18\xbc^Y_\r'
# b'\\JV\xd1\x9e`\x1e\xbc\xf3\xd3b\xc1\xe0\x0eN\xd5' b'\\JV\xd1\x9e`\x1e\xbc\xf3\xd3b\xc1\xe0\x0eN\xd5'
# b'\xf4G\xe0I\xc5@\x0b\x9cu\xff\xe9\x0by\x1f?\x1b' b'\xf4G\xe0I\xc5@\x0b\x9cu\xff\xe9\x0by\x1f?\x1b'
# b'\xc8s\xff\xd3m\xfc\xb9\x8dk\xf6$\xe8\x06\xf5T\x9d' b'\xc8s\xff\xd3m\xfc\xb9\x8dk\xf6$\xe8\x06\xf5T\x9d'
# b"O|\x0e\xb0'd\x1b\xb3\xcfm(\x0f\xb8R]\xc4" b"O|\x0e\xb0'd\x1b\xb3\xcfm(\x0f\xb8R]\xc4"
# b'_\x013Epo\x1c\x1c\xab\x90\t\xc0\xc6{\xd0\xb1' b'_\x013Epo\x1c\x1c\xab\x90\t\xc0\xc6{\xd0\xb1'
# b'j\xb2f\xd39I\x88\x1fr"\xbfo\'\xff\xaf\xe3' b'j\xb2f\xd39I\x88\x1fr"\xbfo\'\xff\xaf\xe3'
# b'\xd2#\x95t"`B\xd0\xd1\xc4\xdam4\xd3\x1a#' b'\xd2#\x95t"`B\xd0\xd1\xc4\xdam4\xd3\x1a#'
# b'<-v\t\x88\xb9\xcd\xa1b\xb9,b\xfd\xb1\xcc\xa3' b'<-v\t\x88\xb9\xcd\xa1b\xb9,b\xfd\xb1\xcc\xa3'
# b'\x8f\xbbO\xf3-\xbc\xab\xd8\xbc\xeb\x80o\xb0M\x87\x1e' b'\x8f\xbbO\xf3-\xbc\xab\xd8\xbc\xeb\x80o\xb0M\x87\x1e'
# b'\xf9\xedE\xa9e;\xc9V%\x0e\xcd\x90U4\x9c\x1a' b'\xf9\xedE\xa9e;\xc9V%\x0e\xcd\x90U4\x9c\x1a'
# b'\t\x9e7oU\xac.\xab#\xec\x9c\xfd\xe1\x17\x8fM' b'\t\x9e7oU\xac.\xab#\xec\x9c\xfd\xe1\x17\x8fM'
# b'a\xe9+\xa6\xdd}u\xb9\x88\x1ew\xcd\x03#\x8a\xcd' b'a\xe9+\xa6\xdd}u\xb9\x88\x1ew\xcd\x03#\x8a\xcd'
# b'\x8bI\xa7\xa1\xb62\x17e\xd5(\xaa\x02uKd\x1d' b'\x8bI\xa7\xa1\xb62\x17e\xd5(\xaa\x02uKd\x1d'
# b'\xa1ow\xdd\xe7t\x14\xc6\xbd\xfcH\xb6\x1d\xa4\x18\x9b' b'\xa1ow\xdd\xe7t\x14\xc6\xbd\xfcH\xb6\x1d\xa4\x18\x9b'
# b'`\xa1k\xc1\x03\x08\x17\xde\x85\xcc\xcdEln1\xdc' b'`\xa1k\xc1\x03\x08\x17\xde\x85\xcc\xcdEln1\xdc'
# b'\xdf\xbe\x15],\xee\x91\xc3\xd0\xd5\xf7\x89\xf5\xcb\xd9u' b'\xdf\xbe\x15],\xee\x91\xc3\xd0\xd5\xf7\x89\xf5\xcb\xd9u'
# b'x\xe2\x87\x04\x80q\xd7\xdb\xc5\xc4\x01\xc3\x9a\x0f\x85\xb9' b'x\xe2\x87\x04\x80q\xd7\xdb\xc5\xc4\x01\xc3\x9a\x0f\x85\xb9'
# b"\xed\xc1',\x12\xe3\x82X\xc7A\\\xef=\xfa\xfb@" b"\xed\xc1',\x12\xe3\x82X\xc7A\\\xef=\xfa\xfb@"
# b'\x98\xfd\xa25\xab\xf5\xbdY>\t\x071C\x98-,' b'\x98\xfd\xa25\xab\xf5\xbdY>\t\x071C\x98-,'
# b'B&(\x8f3p\x8do\xad\xf1\x94\x99J\xe4\x82X' b'B&(\x8f3p\x8do\xad\xf1\x94\x99J\xe4\x82X'
# b'\xf8\xdd\xdc~\xa8\x8aW^\xcd\xc1\xfc\x99AUwB' b'\xf8\xdd\xdc~\xa8\x8aW^\xcd\xc1\xfc\x99AUwB'
# b'd"\xbc\x9f#\xf9\x07\x8c\x12g<\xfa?\xac\xab\xcd' b'd"\xbc\x9f#\xf9\x07\x8c\x12g<\xfa?\xac\xab\xcd'
# b"\xda\x0cT\xcc\x8f)pDgI\x7f\xec\x99'w\xd0" b"\xda\x0cT\xcc\x8f)pDgI\x7f\xec\x99'w\xd0"
# b'\xec\xf34\xa2H)\xe9+\xf8\t\\P\x8c\xbe?\xe6' b'\xec\xf34\xa2H)\xe9+\xf8\t\\P\x8c\xbe?\xe6'
# b'\x99\x0b\x01\xe6\xa1\xc8\x9fB\x82h\xbab\x04Pa\xed' b'\x99\x0b\x01\xe6\xa1\xc8\x9fB\x82h\xbab\x04Pa\xed'
# b'\x03\xc3\xd1\xe6\x89\xb5\x81\xfb\x9fo|\x14\x02\x81*7' b'\x03\xc3\xd1\xe6\x89\xb5\x81\xfb\x9fo|\x14\x02\x81*7'
# b'\x15@\xc1\xf6\xa8\xe7J:&`\xcb\x9c#\x19`\x02' b'\x15@\xc1\xf6\xa8\xe7J:&`\xcb\x9c#\x19`\x02'
# b'\xa9\xc5\xfd\x94$9\t\xe3h,*\x89\xc6\xb4>r' b'\xa9\xc5\xfd\x94$9\t\xe3h,*\x89\xc6\xb4>r'
# b'=\x07\xf0\xd3\xb8\x030c\xba\n\xed/\xd9\xf7\xe8\x1c' b'=\x07\xf0\xd3\xb8\x030c\xba\n\xed/\xd9\xf7\xe8\x1c'
# b'\x02\xce\xbbq4\xcdi\xb2ft\xb5T\n\xde$ ' b'\x02\xce\xbbq4\xcdi\xb2ft\xb5T\n\xde$ '
# b'\xb3\xb1\xff\xd4\xfdZ\xb0\x15(@k-\xff\x8fNL' b'\xb3\xb1\xff\xd4\xfdZ\xb0\x15(@k-\xff\x8fNL'
# b'2b\xb7\xb8sI\xea\xcbw\xcd=OP\x0ex\xa6' b'2b\xb7\xb8sI\xea\xcbw\xcd=OP\x0ex\xa6'
# b'\x00G!\xd3\xc6A\xfa\xe7%\xc2!\x91\x0c\x0exh' b'\x00G!\xd3\xc6A\xfa\xe7%\xc2!\x91\x0c\x0exh'
# b'\xd9\x0f.\\\xed\xdc\xde&f\xfcg\x13\n\x89\xed\xec' b'\xd9\x0f.\\\xed\xdc\xde&f\xfcg\x13\n\x89\xed\xec'
# b"\x95O.\x03\xaa\x94\nQm\xc3\xf4O'D\xeb\xf7" b"\x95O.\x03\xaa\x94\nQm\xc3\xf4O'D\xeb\xf7"
# b'I\xa8\x9a\xa1\xe8\x08\xb4\xc1\xe9\xb5\xcc\xfd\xf3B\xa8(' b'I\xa8\x9a\xa1\xe8\x08\xb4\xc1\xe9\xb5\xcc\xfd\xf3B\xa8('
# b"5Sx,\xb9\x0f\xa8\xd9(m\xf3`\xcd\xa3'\x96" b"5Sx,\xb9\x0f\xa8\xd9(m\xf3`\xcd\xa3'\x96"
# b'\xab\x16$\x91\xffrwB\xb6\xc1\x93i\xabn\x81\xc3' b'\xab\x16$\x91\xffrwB\xb6\xc1\x93i\xabn\x81\xc3'
# b'\xb4\xee\xb7MaG\x1dL\xf9\xaa\xdfz:x\x88\xda' b'\xb4\xee\xb7MaG\x1dL\xf9\xaa\xdfz:x\x88\xda'
# b'\xda]3r\x89J\xc1\xe5\x83\xdc\x80V\xee\x87\xccu' b'\xda]3r\x89J\xc1\xe5\x83\xdc\x80V\xee\x87\xccu'
# b'_9\xd7\x0e\x0c\xa8c\x90\xc9\x83N8\x06Xq\xaa' b'_9\xd7\x0e\x0c\xa8c\x90\xc9\x83N8\x06Xq\xaa'
# b'\x0b_(&\xdb\xb6\x0c\xaaP\xab\xdbE\xa30\x87\xa3' b'\x0b_(&\xdb\xb6\x0c\xaaP\xab\xdbE\xa30\x87\xa3'
# b'\xc0\xffaq}\x07?\xca\x1f\xea|\x95\xc5\xae\x02N' b'\xc0\xffaq}\x07?\xca\x1f\xea|\x95\xc5\xae\x02N'
# "intext0=textin[0]\nintext1=intext0.astype('B')\nintext2=intext1.tobytes()\nencrypted_text = cipher2.encrypt(intext2)\nouttext0=textout[0]\nouttext1=outtext0.astype('B')\nouttext2=outtext1.tobytes()\nprint(outtext2, encrypted_text)"
